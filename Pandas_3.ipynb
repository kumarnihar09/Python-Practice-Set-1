# %% [markdown]
# note : use the orders and returns dataset

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
dfo = pd.read_csv('orders.txt')
dfo.columns = dfo.columns.str.capitalize()
dfo
# Out:
#      <input type="file" id="files-a1c73229-1bc0-4ee8-b2aa-6dcb353c11e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1c73229-1bc0-4ee8-b2aa-6dcb353c11e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
dfr = pd.read_csv('returns.txt')
dfr

# %% [markdown]
# 1- write a program to get category wise sales of orders that were not returned

# %%
filter1 = pd.merge(left=dfo, right=dfr, how='left', left_on='Order_id', right_on='Order Id')
filter2 = filter[filter['Return Reason'].isnull()]
filter2
# filter2.groupby('Category',as_index=False)['Sales'].sum()
# result1 = filter2.groupby('Category')['Sales'].sum()
# pd.DataFrame({'Category':result1.index, 'Sales':result1.values})
# Out:
#             Order_id  Order_date      Customer_name           City  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              Category       Product_id    Sales    Profit Order Id  \
# 0          Technology  TEC-PH-10002075  377.970  109.6113      NaN
# ...

# %% [markdown]
# 2- write a program to get city wise count of return orders

# %%
filter3 = pd.merge(left=dfo, right=dfr, how='inner', left_on='Order_id', right_on='Order Id')
filter3['City'].value_counts()
# Out:
# Los Angeles         50
# Seattle             25
# San Francisco       24
# New York City       11
# San Diego            9
#                     ..
# Bartlett             1
# Boise                1
# Colorado Springs     1
# Medina               1
# Pharr                1
# Name: City, Length: 119, dtype: int64

# %% [markdown]
# 3- write a program to print cities where we have all 3 kinds of returns (others,bad quality,wrong items)

# %%
merged_data = pd.merge(left=dfo, right=dfr, how='inner', left_on='Order_id', right_on='Order Id')
city_counts = merged_data.groupby('City')['Return Reason'].nunique()
# nunique ignores NaN values
city_counts[city_counts.values> 2]
# Out:
# City
# Los Angeles      3
# New York City    3
# Name: Return Reason, dtype: int64

# %% [markdown]
# 4- write a program to find cities where not even a single order was returned.

# %%
merged_data = pd.merge(left=dfo, right=dfr, how='left', left_on='Order_id', right_on='Order Id')
city_single_order = merged_data.groupby('City',as_index=False)['Return Reason'].count()
city_single_order[city_single_order.values == 0]
# Out:
#            City  Return Reason
# 0      Aberdeen              0
# 1       Abilene              0
# 2         Akron              0
# 4    Alexandria              0
# 5         Allen              0
# ..          ...            ...
# 525   Woodstock              0
# 526  Woonsocket              0
# 527     Yonkers              0
# 529     Yucaipa              0
# 530        Yuma              0
#
# [412 rows x 2 columns]

# %% [markdown]
# 5- write a program to find top 3 cities by sales

# %%
merged_data = pd.merge(left=dfo, right=dfr, how='inner', left_on='Order_id', right_on='Order Id')
top_sales_city = merged_data.groupby('City')['Sales'].sum().sort_values(ascending=False).head(3)
top_sales_city
# top_sales_city[top_sales_city.sort_values(ascending=False)]
# Out:
# City
# Los Angeles      11257.4545
# San Francisco     5943.3340
# Seattle           5209.2960
# Name: Sales, dtype: float64

# %% [markdown]
# 6- write a program to get order ids whos return reason is not known (nan)

# %%
# merged_data = pd.merge(left=dfo, right=dfr, how='inner', left_on='Order_id', right_on='Order Id')
dfr[dfr['Return Reason'].isna()]
# dfr[dfr['Return Reason'].isnull()]
# Out:
#            Order Id Return Reason
# 11   CA-2020-114307           NaN
# 29   CA-2020-133368           NaN
# 107  CA-2018-105270           NaN
# 142  CA-2018-164721           NaN
# 149  CA-2019-105158           NaN

# %% [markdown]
# 7- write a program to fill unknown return reason to a default value 'others'

# %%
dfr['Return Reason'].fillna('others',inplace=True)
dfr
# Out:
#            Order Id Return Reason
# 0    CA-2020-104689   Wrong Items
# 1    CA-2020-105081   Wrong Items
# 2    CA-2020-105291   Wrong Items
# 3    CA-2020-105585   Wrong Items
# 4    CA-2020-106950   Wrong Items
# ..              ...           ...
# 291  US-2021-136679        Others
# 292  US-2021-147886        Others
# 293  US-2021-147998   Wrong Items
# 294  US-2021-151127   Wrong Items
# 295  US-2021-155999   Wrong Items
#
# [296 rows x 2 columns]

# %% [markdown]
# 8- write a program to find avg sales and avg profit for each category

# %%
merged_data = pd.merge(left=dfo, right=dfr, how='inner', left_on='Order_id', right_on='Order Id')
merged_data.groupby('Category').agg({'Sales':'mean','Profit':'mean'})
# Out:
#                       Sales     Profit
# Category
# Furniture        337.821029   8.787498
# Office Supplies   99.861879  24.061600
# Technology       316.115263  40.730758
